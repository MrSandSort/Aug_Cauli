# %%
import requests 
import os
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from PIL import Image
from io import BytesIO

# %%
url= "https://www.daraz.com.np/"
response= requests.get(url)
soup= BeautifulSoup(response.text,'html.parser')

img_tags= soup.find_all('img')

desktop_path = os.path.join(os.path.expanduser("~"), "Desktop", "images")
os.makedirs(desktop_path, exist_ok=True)

# %%
for img in img_tags:
    
    img_url = img.get('src')
    img_url = urljoin(url, img_url)
    
    img_response = requests.get(img_url)
    if img_response.status_code == 200:
        content_type = img_response.headers.get('Content-Type')
        
        if 'image' in content_type:
            try:
          
                img_data = Image.open(BytesIO(img_response.content))
                
             
                parsed_url = urlparse(img_url)
                img_name = os.path.join(desktop_path, os.path.basename(parsed_url.path))
                
               
                if not img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp')):
                    img_name += '.jpg' 
                
                img_data.save(img_name)
                print(f"Downloaded {img_name}")
                
            except Exception as e:
                print(f"Failed to process image {img_url}: {e}")
        else:
            print(f"URL does not point to an image: {img_url}")
    else:
        print(f"Failed to retrieve image. Status code: {img_response.status_code}")
# Out:
# Downloaded images\O1CN01da6D0K1Khogk708ZP_!!6000000001196-0-tps-150-150.jpg
# Downloaded images\3b870cb043c7f8a9741cbf66329e294e.png
# Downloaded images\dd8ecc2c-8956-44ab-a5fa-bb1f3fa908ee_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded images\dafd61e7-be65-4e3a-9780-44d8eeadb336_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded images\d2c2bdae-0c23-4b8d-8a19-6d25c59e1c2c_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded images\be5d76df-d6f0-40b2-8dce-78cb97900ff0_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded images\0ab4bb6a-cfcd-4c88-8111-754f839e6df7_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded images\653c5207-f7e8-4289-9779-e3d45c9232ca_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded images\920077d2-d58c-4136-8458-c554d96be31d_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded images\40db9b75-b3fd-4dec-b1c8-6b0f6886f972_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded images\47c46112-f5f1-406d-a511-b286832d9019_NP-1976-688.png_2200x2200q80.png
# Downloaded images\2f0e3da0-4d0b-495a-a53a-eec51c004e1d_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded images\e01a7fda-88a1-4009-9544-2984d0a2b35e_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded images\b576b427-3613-4f11-97e1-4bc83b92e8ce_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded images\4e7bacde-acf2-45f7-b734-704cafac7c95_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded images\61b053d9-9777-4077-b0d3-e2f07a07f6ff_NP-1976-688.jpg_2200x2200q80.jpg
# Downloaded images\1ee015d6a5c62fd0339c88c657c1c183.jpg_120x120q80.jpg
# Downloaded images\O1CN01cAMOjU1zqQJZU8EbT_!!6000000006765-2-tps-19-18.png_80x80q80.png
# Downloaded images\O1CN01n3PMa828kJZVuCbPp_!!6000000007970-2-tps-72-72.png_150x150q80.png
# Downloaded images\O1CN01J03SMW1lebTE7xkaN_!!6000000004844-2-tps-72-72.png_150x150q80.png
# Downloaded images\O1CN01da6D0K1Khogk708ZP_!!6000000001196-0-tps-150-150.jpg_360x360q80.jpg
# Downloaded images\0736aba5494ff4dea4ddff388fbe493f.png_400x400q80.png
# Downloaded images\a958bd5d681dc1344facfd34b8fc5ef6.jpg_400x400q80.jpg
# Downloaded images\42cc1108c37e154b64e2b4485519b1bd.jpg_400x400q80.jpg
# Downloaded images\494d10c777d67e405291b6fcf1c89775.jpg_400x400q80.jpg
# Downloaded images\5f0c58212de067656bdf23475825c0f7.jpg_400x400q80.jpg
